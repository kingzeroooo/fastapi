# %% [markdown]
# # 攀岩与越野跑运动手表选购报告（渲染预览）
#
# **如何查看渲染后的页面：**
# 1. 运行下方代码单元格（▶ 或 `Shift+Enter`）
# 2. 渲染结果会显示在本单元格下方
#
# > 说明：在 Cursor 中直接点击 `.html` 文件只会打开源码，这是编辑器默认行为。
# > 请使用本 Notebook 预览，或右键 HTML 文件选择 **Open in Integrated Browser**。

# %%
from pathlib import Path
from IPython.display import HTML, display

report = Path('sports-watch-comparison-report.html')
if not report.exists():
    raise FileNotFoundError('请先确保 sports-watch-comparison-report.html 与本 notebook 在同一目录')

display(HTML(report.read_text(encoding='utf-8')))
